# %%
import numpy as np
import pandas as pd

pd.set_option('compute.use_numexpr', False)
pd.__version__

url = 'data/weather.csv'
df = pd.read_csv(url, engine='pyarrow', dtype_backend='pyarrow')
df.shape
# Out:
# (500, 31)

# %%
df.describe()
# Out:
#        station_number   wban_number        year       month         day  \
# count      500.000000    500.000000   500.00000  500.000000  500.000000
# mean    145457.528000  98317.760000  1932.13800    6.732000   16.484000
# std     169720.822587  11221.016064     1.33811    3.420464    8.793201
# min      30050.000000  23119.000000  1929.00000    1.000000    1.000000
# 25%      35750.000000  99999.000000  1931.00000    4.000000    9.000000
# 50%      39730.000000  99999.000000  1932.00000    7.000000   17.000000
# 75%     267020.000000  99999.000000  1933.00000   10.000000   24.000000
# max     990061.000000  99999.000000  1934.00000   12.000000   31.000000
#
#         mean_temp  num_mean_temp_samples  mean_dew_point  \
# count  500.000000             500.000000      347.000000
# mean    47.734800               4.834000       45.252161
# std     16.264887               2.770161        9.419250
# min    -22.200001               4.000000       10.200000
# ...

# %%
df.query('tornado == True')
# Out:
#      station_number  wban_number  year  month  day  mean_temp  \
# 6             33790        99999  1929      9   17  55.700001
# 32            39800        99999  1930      7    4  56.299999
# 39            38940        99999  1930      7    9  62.500000
# 42            38040        99999  1930      5   14  52.000000
# 44            36010        99999  1930      8   30  59.299999
# 45            37950        99999  1930      9   30  52.200001
# 51            37770        99999  1930     12    9  36.000000
# 63            32620        99999  1930     12   12  40.200001
# 64            39800        99999  1930      9   11  52.200001
# 106           37950        99999  1931      5   12  53.799999
# 153          726810        24131  1931      1   16  35.299999
# 165           32620        99999  1932      6    2  47.200001
# 171           37950        99999  1932      1   19  49.000000
# 187          106090        99999  1932      8   18  80.699997
# ...
