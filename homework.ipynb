# %%
# Create a cell containing all the imports for this notebook
# Create a cell with the clean_housing and shrink_ints functions
# Add code to load the raw data and create a housing variable from calling clean_housing
# Move those cells to the top of the notebook
# Restart the notebook and make sure that those cells work

import pandas as pd
import numpy as np
url = 'data/ames-housing-dataset.zip'



def shrink_ints(df):
    mapping = {}
    for col in df.dtypes[df.dtypes=="int64[pyarrow]"].index:
        max_ = df[col].max()
        min_ = df[col].min()
        if min_ < 0:
            continue
        if max_ < 255:
            mapping[col] = "uint8[pyarrow]"
        elif max_ < 65_535:
            mapping[col] = "uint16[pyarrow]"
        elif max_< 4_294_967_295:
            mapping[col] = "uint32[pyarrow]"
    return df.astype(mapping)


def clean_housing(df):
    return (df
        .assign(**df.select_dtypes('string').replace('','Missing').astype('category'),
                **{'Garage Yr Blt':df['Garage Yr Blt'].clip(upper=df['Year Built'].max())})
        .pipe(shrink_ints)
    )
raw = pd.read_csv(url,engine="pyarrow", dtype_backend="pyarrow")
housing = clean_housing(raw)

# %%
with pd.option_context('display.min_rows', 30, 'display.max_columns', 82):
    display(raw)
housing
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL           141     31770   Pave
# 1         2  526350040           20        RH            80     11622   Pave
# 2         3  526351010           20        RL            81     14267   Pave
# 3         4  526353030           20        RL            93     11160   Pave
# 4         5  527105010           60        RL            74     13830   Pave
# 5         6  527105030           60        RL            78      9978   Pave
# 6         7  527127150          120        RL            41      4920   Pave
# 7         8  527145080          120        RL            43      5005   Pave
# 8         9  527146030          120        RL            39      5389   Pave
# 9        10  527162130           60        RL            60      7500   Pave
# 10       11  527163010           60        RL            75     10000   Pave
# 11       12  527165230           20        RL          <NA>      7980   Pave
# 12       13  527166040           60        RL            63      8402   Pave
# 13       14  527180040           20        RL            85     10176   Pave
# 14       15  527182190          120        RL          <NA>      6820   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2915   2916  923227100           20        RL            80     13384   Pave
# 2916   2917  923228130          180        RM            21      1533   Pave
# 2917   2918  923228180          160        RM            21      1533   Pave
# 2918   2919  923228210          160        RM            21      1526   Pave
# 2919   2920  923228260          160        RM            21      1936   Pave
# 2920   2921  923228310          160        RM            21      1894   Pave
# 2921   2922  923229110           90        RL            55     12640   Pave
# 2922   2923  923230040           90        RL            63      9297   Pave
# 2923   2924  923250060           20        RL            80     17400   Pave
# 2924   2925  923251180           20        RL           160     20000   Pave
# 2925   2926  923275080           80        RL            37      7937   Pave
# 2926   2927  923276100           20        RL          <NA>      8885   Pave
# 2927   2928  923400125           85        RL            62     10441   Pave
# 2928   2929  924100070           20        RL            77     10010   Pave
# 2929   2930  924151050           60        RL            74      9627   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0       NA       IR1          Lvl    AllPub     Corner        Gtl
# 1       NA       Reg          Lvl    AllPub     Inside        Gtl
# 2       NA       IR1          Lvl    AllPub     Corner        Gtl
# 3       NA       Reg          Lvl    AllPub     Corner        Gtl
# 4       NA       IR1          Lvl    AllPub     Inside        Gtl
# 5       NA       IR1          Lvl    AllPub     Inside        Gtl
# 6       NA       Reg          Lvl    AllPub     Inside        Gtl
# 7       NA       IR1          HLS    AllPub     Inside        Gtl
# 8       NA       IR1          Lvl    AllPub     Inside        Gtl
# 9       NA       Reg          Lvl    AllPub     Inside        Gtl
# 10      NA       IR1          Lvl    AllPub     Corner        Gtl
# 11      NA       IR1          Lvl    AllPub     Inside        Gtl
# 12      NA       IR1          Lvl    AllPub     Inside        Gtl
# 13      NA       Reg          Lvl    AllPub     Inside        Gtl
# 14      NA       IR1          Lvl    AllPub     Corner        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2915    NA       Reg          Lvl    AllPub     Inside        Mod
# 2916    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2917    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2918    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2919    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2920    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2921    NA       IR1          Lvl    AllPub     Inside        Gtl
# 2922    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2923    NA       Reg          Low    AllPub     Inside        Mod
# 2924    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2925    NA       IR1          Lvl    AllPub    CulDSac        Gtl
# 2926    NA       IR1          Low    AllPub     Inside        Mod
# 2927    NA       Reg          Lvl    AllPub     Inside        Gtl
# 2928    NA       Reg          Lvl    AllPub     Inside        Mod
# 2929    NA       Reg          Lvl    AllPub     Inside        Mod
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 0           NAmes        Norm        Norm      1Fam      1Story             6
# 1           NAmes       Feedr        Norm      1Fam      1Story             5
# 2           NAmes        Norm        Norm      1Fam      1Story             6
# 3           NAmes        Norm        Norm      1Fam      1Story             7
# 4         Gilbert        Norm        Norm      1Fam      2Story             5
# 5         Gilbert        Norm        Norm      1Fam      2Story             6
# 6         StoneBr        Norm        Norm    TwnhsE      1Story             8
# 7         StoneBr        Norm        Norm    TwnhsE      1Story             8
# 8         StoneBr        Norm        Norm    TwnhsE      1Story             8
# 9         Gilbert        Norm        Norm      1Fam      2Story             7
# 10        Gilbert        Norm        Norm      1Fam      2Story             6
# 11        Gilbert        Norm        Norm      1Fam      1Story             6
# 12        Gilbert        Norm        Norm      1Fam      2Story             6
# 13        Gilbert        Norm        Norm      1Fam      1Story             7
# 14        StoneBr        Norm        Norm    TwnhsE      1Story             8
# ...           ...         ...         ...       ...         ...           ...
# 2915      Mitchel        Norm        Norm      1Fam      1Story             5
# 2916      MeadowV        Norm        Norm     Twnhs      SFoyer             5
# 2917      MeadowV        Norm        Norm     Twnhs      2Story             4
# 2918      MeadowV        Norm        Norm     Twnhs      2Story             4
# 2919      MeadowV        Norm        Norm     Twnhs      2Story             4
# 2920      MeadowV        Norm        Norm    TwnhsE      2Story             4
# 2921      Mitchel        Norm        Norm    Duplex      1Story             6
# 2922      Mitchel        Norm        Norm    Duplex      1Story             5
# 2923      Mitchel        Norm        Norm      1Fam      1Story             5
# 2924      Mitchel        Norm        Norm      1Fam      1Story             5
# 2925      Mitchel        Norm        Norm      1Fam        SLvl             6
# 2926      Mitchel        Norm        Norm      1Fam      1Story             5
# 2927      Mitchel        Norm        Norm      1Fam      SFoyer             5
# 2928      Mitchel        Norm        Norm      1Fam      1Story             5
# 2929      Mitchel        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 0                5        1960            1960        Hip   CompShg
# 1                6        1961            1961      Gable   CompShg
# 2                6        1958            1958        Hip   CompShg
# 3                5        1968            1968        Hip   CompShg
# 4                5        1997            1998      Gable   CompShg
# 5                6        1998            1998      Gable   CompShg
# 6                5        2001            2001      Gable   CompShg
# 7                5        1992            1992      Gable   CompShg
# 8                5        1995            1996      Gable   CompShg
# 9                5        1999            1999      Gable   CompShg
# 10               5        1993            1994      Gable   CompShg
# 11               7        1992            2007      Gable   CompShg
# 12               5        1998            1998      Gable   CompShg
# 13               5        1990            1990      Gable   CompShg
# 14               5        1985            1985      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2915             5        1969            1979      Gable   CompShg
# 2916             7        1970            1970      Gable   CompShg
# 2917             5        1970            1970      Gable   CompShg
# 2918             5        1970            1970      Gable   CompShg
# 2919             7        1970            1970      Gable   CompShg
# 2920             5        1970            1970      Gable   CompShg
# 2921             5        1976            1976      Gable   CompShg
# 2922             5        1976            1976      Gable   CompShg
# 2923             5        1977            1977      Gable   CompShg
# 2924             7        1960            1996      Gable   CompShg
# 2925             6        1984            1984      Gable   CompShg
# 2926             5        1983            1983      Gable   CompShg
# 2927             5        1992            1992      Gable   CompShg
# 2928             5        1974            1975      Gable   CompShg
# 2929             5        1993            1994      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 0         BrkFace      Plywood        Stone           112         TA
# 1         VinylSd      VinylSd         None             0         TA
# 2         Wd Sdng      Wd Sdng      BrkFace           108         TA
# 3         BrkFace      BrkFace         None             0         Gd
# 4         VinylSd      VinylSd         None             0         TA
# 5         VinylSd      VinylSd      BrkFace            20         TA
# 6         CemntBd      CmentBd         None             0         Gd
# 7         HdBoard      HdBoard         None             0         Gd
# 8         CemntBd      CmentBd         None             0         Gd
# 9         VinylSd      VinylSd         None             0         TA
# 10        HdBoard      HdBoard         None             0         TA
# 11        HdBoard      HdBoard         None             0         TA
# 12        VinylSd      VinylSd         None             0         TA
# 13        HdBoard      HdBoard         None             0         TA
# 14        HdBoard      HdBoard         None             0         Gd
# ...           ...          ...          ...           ...        ...
# 2915      Plywood      Plywood      BrkFace           194         TA
# 2916      CemntBd      CmentBd         None             0         TA
# 2917      CemntBd      CmentBd         None             0         TA
# 2918      CemntBd      CmentBd         None             0         TA
# 2919      CemntBd      CmentBd         None             0         TA
# 2920      CemntBd      CmentBd         None             0         TA
# 2921      Plywood      Plywood         None             0         TA
# 2922      Plywood      Plywood         None             0         TA
# 2923      BrkFace      BrkFace         None             0         TA
# 2924      VinylSd      VinylSd         None             0         TA
# 2925      HdBoard      HdBoard         None             0         TA
# 2926      HdBoard      HdBoard         None             0         TA
# 2927      HdBoard      Wd Shng         None             0         TA
# 2928      HdBoard      HdBoard         None             0         TA
# 2929      HdBoard      HdBoard      BrkFace            94         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA     CBlock        TA        Gd            Gd            BLQ
# 1            TA     CBlock        TA        TA            No            Rec
# 2            TA     CBlock        TA        TA            No            ALQ
# 3            TA     CBlock        TA        TA            No            ALQ
# 4            TA      PConc        Gd        TA            No            GLQ
# 5            TA      PConc        TA        TA            No            GLQ
# 6            TA      PConc        Gd        TA            Mn            GLQ
# 7            TA      PConc        Gd        TA            No            ALQ
# 8            TA      PConc        Gd        TA            No            GLQ
# 9            TA      PConc        TA        TA            No            Unf
# 10           TA      PConc        Gd        TA            No            Unf
# 11           Gd      PConc        Gd        TA            No            ALQ
# 12           TA      PConc        Gd        TA            No            Unf
# 13           TA      PConc        Gd        TA            Gd            GLQ
# 14           TA      PConc        Gd        TA            Av            GLQ
# ...         ...        ...       ...       ...           ...            ...
# 2915         TA      PConc        TA        TA            Av            Rec
# 2916         TA     CBlock        Gd        TA            Av            GLQ
# 2917         TA     CBlock        TA        TA            No            Rec
# 2918         TA     CBlock        TA        TA            No            Unf
# 2919         TA     CBlock        TA        TA            No            Unf
# 2920         TA     CBlock        TA        TA            No            Rec
# 2921         TA     CBlock        TA        TA            Gd            Rec
# 2922         TA     CBlock        TA        TA            No            ALQ
# 2923         TA     CBlock        TA        TA            No            ALQ
# 2924         TA     CBlock        TA        TA            No            ALQ
# 2925         TA     CBlock        TA        TA            Av            GLQ
# 2926         TA     CBlock        Gd        TA            Av            BLQ
# 2927         TA      PConc        Gd        TA            Av            GLQ
# 2928         TA     CBlock        Gd        TA            Av            ALQ
# 2929         TA      PConc        Gd        TA            Av            LwQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 0              639            Unf             0          441           1080
# 1              468            LwQ           144          270            882
# 2              923            Unf             0          406           1329
# 3             1065            Unf             0         1045           2110
# 4              791            Unf             0          137            928
# 5              602            Unf             0          324            926
# 6              616            Unf             0          722           1338
# 7              263            Unf             0         1017           1280
# 8             1180            Unf             0          415           1595
# 9                0            Unf             0          994            994
# 10               0            Unf             0          763            763
# 11             935            Unf             0          233           1168
# 12               0            Unf             0          789            789
# 13             637            Unf             0          663           1300
# 14             368            BLQ          1120            0           1488
# ...            ...            ...           ...          ...            ...
# 2915           119            BLQ           344          641           1104
# 2916           553            Unf             0           77            630
# 2917           408            Unf             0          138            546
# 2918             0            Unf             0          546            546
# 2919             0            Unf             0          546            546
# 2920           252            Unf             0          294            546
# 2921           936            LwQ           396          396           1728
# 2922          1606            Unf             0          122           1728
# 2923           936            Unf             0          190           1126
# 2924          1224            Unf             0            0           1224
# 2925           819            Unf             0          184           1003
# 2926           301            ALQ           324          239            864
# 2927           337            Unf             0          575            912
# 2928          1071            LwQ           123          195           1389
# 2929           758            Unf             0          238            996
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0       GasA         Fa           Y      SBrkr        1656           0
# 1       GasA         TA           Y      SBrkr         896           0
# 2       GasA         TA           Y      SBrkr        1329           0
# 3       GasA         Ex           Y      SBrkr        2110           0
# 4       GasA         Gd           Y      SBrkr         928         701
# 5       GasA         Ex           Y      SBrkr         926         678
# 6       GasA         Ex           Y      SBrkr        1338           0
# 7       GasA         Ex           Y      SBrkr        1280           0
# 8       GasA         Ex           Y      SBrkr        1616           0
# 9       GasA         Gd           Y      SBrkr        1028         776
# 10      GasA         Gd           Y      SBrkr         763         892
# 11      GasA         Ex           Y      SBrkr        1187           0
# 12      GasA         Gd           Y      SBrkr         789         676
# 13      GasA         Gd           Y      SBrkr        1341           0
# 14      GasA         TA           Y      SBrkr        1502           0
# ...      ...        ...         ...        ...         ...         ...
# 2915    GasA         Fa           Y      SBrkr        1360           0
# 2916    GasA         Ex           Y      SBrkr         630           0
# 2917    GasA         TA           Y      SBrkr         546         546
# 2918    GasA         TA           Y      SBrkr         546         546
# 2919    GasA         Gd           Y      SBrkr         546         546
# 2920    GasA         TA           Y      SBrkr         546         546
# 2921    GasA         TA           Y      SBrkr        1728           0
# 2922    GasA         TA           Y      SBrkr        1728           0
# 2923    GasA         Fa           Y      SBrkr        1126           0
# 2924    GasA         Ex           Y      SBrkr        1224           0
# 2925    GasA         TA           Y      SBrkr        1003           0
# 2926    GasA         TA           Y      SBrkr         902           0
# 2927    GasA         TA           Y      SBrkr         970           0
# 2928    GasA         Gd           Y      SBrkr        1389           0
# 2929    GasA         Ex           Y      SBrkr         996        1004
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0                   0         1656               1               0          1
# 1                   0          896               0               0          1
# 2                   0         1329               0               0          1
# 3                   0         2110               1               0          2
# 4                   0         1629               0               0          2
# 5                   0         1604               0               0          2
# 6                   0         1338               1               0          2
# 7                   0         1280               0               0          2
# 8                   0         1616               1               0          2
# 9                   0         1804               0               0          2
# 10                  0         1655               0               0          2
# 11                  0         1187               1               0          2
# 12                  0         1465               0               0          2
# 13                  0         1341               1               0          1
# 14                  0         1502               1               0          1
# ...               ...          ...             ...             ...        ...
# 2915                0         1360               1               0          1
# 2916                0          630               1               0          1
# 2917                0         1092               0               0          1
# 2918                0         1092               0               0          1
# 2919                0         1092               0               0          1
# 2920                0         1092               0               0          1
# 2921                0         1728               0               0          2
# 2922                0         1728               2               0          2
# 2923                0         1126               1               0          2
# 2924                0         1224               1               0          1
# 2925                0         1003               1               0          1
# 2926                0          902               1               0          1
# 2927                0          970               0               1          1
# 2928                0         1389               1               0          1
# 2929                0         2000               0               0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 0             0              3              1           TA              7
# 1             0              2              1           TA              5
# 2             1              3              1           Gd              6
# 3             1              3              1           Ex              8
# 4             1              3              1           TA              6
# 5             1              3              1           Gd              7
# 6             0              2              1           Gd              6
# 7             0              2              1           Gd              5
# 8             0              2              1           Gd              5
# 9             1              3              1           Gd              7
# 10            1              3              1           TA              7
# 11            0              3              1           TA              6
# 12            1              3              1           TA              7
# 13            1              2              1           Gd              5
# 14            1              1              1           Gd              4
# ...         ...            ...            ...          ...            ...
# 2915          0              3              1           TA              8
# 2916          0              1              1           Ex              3
# 2917          1              3              1           TA              5
# 2918          1              3              1           TA              5
# 2919          1              3              1           TA              5
# 2920          1              3              1           TA              6
# 2921          0              4              2           TA              8
# 2922          0              4              2           TA              8
# 2923          0              3              1           TA              5
# 2924          0              4              1           TA              7
# 2925          0              3              1           TA              6
# 2926          0              2              1           TA              5
# 2927          0              3              1           TA              6
# 2928          0              2              1           TA              6
# 2929          1              3              1           TA              9
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 0           Typ           2           Gd      Attchd           1960
# 1           Typ           0           NA      Attchd           1961
# 2           Typ           0           NA      Attchd           1958
# 3           Typ           2           TA      Attchd           1968
# 4           Typ           1           TA      Attchd           1997
# 5           Typ           1           Gd      Attchd           1998
# 6           Typ           0           NA      Attchd           2001
# 7           Typ           0           NA      Attchd           1992
# 8           Typ           1           TA      Attchd           1995
# 9           Typ           1           TA      Attchd           1999
# 10          Typ           1           TA      Attchd           1993
# 11          Typ           0           NA      Attchd           1992
# 12          Typ           1           Gd      Attchd           1998
# 13          Typ           1           Po      Attchd           1990
# 14          Typ           0           NA      Attchd           1985
# ...         ...         ...          ...         ...            ...
# 2915        Typ           1           TA      Attchd           1969
# 2916        Typ           0           NA          NA           <NA>
# 2917        Typ           0           NA     CarPort           1970
# 2918        Typ           0           NA          NA           <NA>
# 2919        Typ           0           NA          NA           <NA>
# 2920        Typ           0           NA     CarPort           1970
# 2921        Typ           0           NA      Attchd           1976
# 2922        Typ           0           NA      Detchd           1976
# 2923        Typ           1           Gd      Attchd           1977
# 2924        Typ           1           TA      Detchd           1960
# 2925        Typ           0           NA      Detchd           1984
# 2926        Typ           0           NA      Attchd           1983
# 2927        Typ           0           NA          NA           <NA>
# 2928        Typ           1           TA      Attchd           1975
# 2929        Typ           1           TA      Attchd           1993
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0              Fin            2          528          TA          TA
# 1              Unf            1          730          TA          TA
# 2              Unf            1          312          TA          TA
# 3              Fin            2          522          TA          TA
# 4              Fin            2          482          TA          TA
# 5              Fin            2          470          TA          TA
# 6              Fin            2          582          TA          TA
# 7              RFn            2          506          TA          TA
# 8              RFn            2          608          TA          TA
# 9              Fin            2          442          TA          TA
# 10             Fin            2          440          TA          TA
# 11             Fin            2          420          TA          TA
# 12             Fin            2          393          TA          TA
# 13             Unf            2          506          TA          TA
# 14             RFn            2          528          TA          TA
# ...            ...          ...          ...         ...         ...
# 2915           RFn            1          336          TA          TA
# 2916            NA            0            0          NA          NA
# 2917           Unf            1          286          TA          TA
# 2918            NA            0            0          NA          NA
# 2919            NA            0            0          NA          NA
# 2920           Unf            1          286          TA          TA
# 2921           Unf            2          574          TA          TA
# 2922           Unf            2          560          TA          TA
# 2923           RFn            2          484          TA          TA
# 2924           Unf            2          576          TA          TA
# 2925           Unf            2          588          TA          TA
# 2926           Unf            2          484          TA          TA
# 2927            NA            0            0          NA          NA
# 2928           RFn            2          418          TA          TA
# 2929           Fin            3          650          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0              P           210             62               0           0
# 1              Y           140              0               0           0
# 2              Y           393             36               0           0
# 3              Y             0              0               0           0
# 4              Y           212             34               0           0
# 5              Y           360             36               0           0
# 6              Y             0              0             170           0
# 7              Y             0             82               0           0
# 8              Y           237            152               0           0
# 9              Y           140             60               0           0
# 10             Y           157             84               0           0
# 11             Y           483             21               0           0
# 12             Y             0             75               0           0
# 13             Y           192              0               0           0
# 14             Y             0             54               0           0
# ...          ...           ...            ...             ...         ...
# 2915           Y           160              0               0           0
# 2916           Y             0              0               0           0
# 2917           Y             0              0               0           0
# 2918           Y             0             34               0           0
# 2919           Y             0              0               0           0
# 2920           Y             0             24               0           0
# 2921           Y            40              0               0           0
# 2922           Y             0              0               0           0
# 2923           P           295             41               0           0
# 2924           Y           474              0               0           0
# 2925           Y           120              0               0           0
# 2926           Y           164              0               0           0
# 2927           Y            80             32               0           0
# 2928           Y           240             38               0           0
# 2929           Y           190             48               0           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 0                0          0      NA     NA           NA         0        5
# 1              120          0      NA  MnPrv           NA         0        6
# 2                0          0      NA     NA         Gar2     12500        6
# 3                0          0      NA     NA           NA         0        4
# 4                0          0      NA  MnPrv           NA         0        3
# 5                0          0      NA     NA           NA         0        6
# 6                0          0      NA     NA           NA         0        4
# 7              144          0      NA     NA           NA         0        1
# 8                0          0      NA     NA           NA         0        3
# 9                0          0      NA     NA           NA         0        6
# 10               0          0      NA     NA           NA         0        4
# 11               0          0      NA  GdPrv         Shed       500        3
# 12               0          0      NA     NA           NA         0        5
# 13               0          0      NA     NA           NA         0        2
# 14             140          0      NA     NA           NA         0        6
# ...            ...        ...     ...    ...          ...       ...      ...
# 2915             0          0      NA     NA           NA         0        5
# 2916             0          0      NA     NA           NA         0        8
# 2917             0          0      NA     NA           NA         0       12
# 2918             0          0      NA  GdPrv           NA         0        6
# 2919             0          0      NA     NA           NA         0        6
# 2920             0          0      NA     NA           NA         0        4
# 2921             0          0      NA     NA           NA         0        7
# 2922             0          0      NA     NA           NA         0        7
# 2923             0          0      NA     NA           NA         0        5
# 2924             0          0      NA     NA           NA         0        9
# 2925             0          0      NA  GdPrv           NA         0        3
# 2926             0          0      NA  MnPrv           NA         0        6
# 2927             0          0      NA  MnPrv         Shed       700        7
# 2928             0          0      NA     NA           NA         0        4
# 2929             0          0      NA     NA           NA         0       11
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 0        2010       WD          Normal     215000
# 1        2010       WD          Normal     105000
# 2        2010       WD          Normal     172000
# 3        2010       WD          Normal     244000
# 4        2010       WD          Normal     189900
# 5        2010       WD          Normal     195500
# 6        2010       WD          Normal     213500
# 7        2010       WD          Normal     191500
# 8        2010       WD          Normal     236500
# 9        2010       WD          Normal     189000
# 10       2010       WD          Normal     175900
# 11       2010       WD          Normal     185000
# 12       2010       WD          Normal     180400
# 13       2010       WD          Normal     171500
# 14       2010       WD          Normal     212000
# ...       ...       ...            ...        ...
# 2915     2006       WD          Normal     140000
# 2916     2006       WD         Abnorml      92000
# 2917     2006       WD         Abnorml      87550
# 2918     2006       WD          Normal      79500
# 2919     2006       WD          Normal      90500
# 2920     2006       WD         Abnorml      71000
# 2921     2006       WD          Normal     150900
# 2922     2006       WD          Family     188000
# 2923     2006       WD          Normal     160000
# 2924     2006       WD         Abnorml     131000
# 2925     2006       WD          Normal     142500
# 2926     2006       WD          Normal     131000
# 2927     2006       WD          Normal     132000
# 2928     2006       WD          Normal     170000
# 2929     2006       WD          Normal     188000
#
# [2930 rows x 82 columns]
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL           141     31770   Pave
# 1         2  526350040           20        RH            80     11622   Pave
# 2         3  526351010           20        RL            81     14267   Pave
# 3         4  526353030           20        RL            93     11160   Pave
# 4         5  527105010           60        RL            74     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL            37      7937   Pave
# 2926   2927  923276100           20        RL          <NA>      8885   Pave
# 2927   2928  923400125           85        RL            62     10441   Pave
# 2928   2929  924100070           20        RL            77     10010   Pave
# 2929   2930  924151050           60        RL            74      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       NA       IR1          Lvl  ...         0      NA     NA           NA
# 1       NA       Reg          Lvl  ...         0      NA  MnPrv           NA
# 2       NA       IR1          Lvl  ...         0      NA     NA         Gar2
# 3       NA       Reg          Lvl  ...         0      NA     NA           NA
# 4       NA       IR1          Lvl  ...         0      NA  MnPrv           NA
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2925    NA       IR1          Lvl  ...         0      NA  GdPrv           NA
# 2926    NA       IR1          Low  ...         0      NA  MnPrv           NA
# 2927    NA       Reg          Lvl  ...         0      NA  MnPrv         Shed
# 2928    NA       Reg          Lvl  ...         0      NA     NA           NA
# 2929    NA       Reg          Lvl  ...         0      NA     NA           NA
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# 2       12500       6    2010       WD           Normal     172000
# 3           0       4    2010       WD           Normal     244000
# 4           0       3    2010       WD           Normal     189900
# ...       ...     ...     ...       ...             ...        ...
# 2925        0       3    2006       WD           Normal     142500
# 2926        0       6    2006       WD           Normal     131000
# 2927      700       7    2006       WD           Normal     132000
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %%
(housing['MS Zoning'].value_counts()
    .plot.bar())
# Out:
# <Axes: xlabel='MS Zoning'>
